# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
load_dotenv()
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi import NewsApiClient
# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\scott\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv()
news_api_key = os.getenv("news_api")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=news_api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_headlines = newsapi.get_everything(q='bitcoin', language='en', sort_by='relevancy')
print(f"Total articles about Bitcoin: {bitcoin_headlines['totalResults']}")
bitcoin_headlines["articles"][0]
# Out:
# Total articles about Bitcoin: 7047
# {'source': {'id': 'wired', 'name': 'Wired'},
#  'author': 'Gian M. Volpicelli',
#  'title': 'The Rise and Fall of a Bitcoin Mining Sensation',
#  'description': 'Compass Mining grew quickly during crypto’s halcyon days. Now, its customers and their thousands of mining machines are stuck.',
#  'url': 'https://www.wired.com/story/compass-mining-bitcoin-russia/',
#  'urlToImage': 'https://media.wired.com/photos/62e9c5e1d7368105da057de3/191:100/w_1280,c_limit/BitRiver-Mining-Center-Rise-And-Fall-Of-Bitcoin-Mining-Business-1184520941.jpg',
#  'publishedAt': '2022-08-03T11:00:00Z',
#  'content': "It was 8:45 in the morning of June 13 when Bill Stewart, the CEO of Maine-based bitcoin mining business Dynamics Mining, received a call from one of his employees. He's like, Every machine inside of … [+3472 chars]"}

# %%
# Fetch the Ethereum news articles
ethereum_headlines = newsapi.get_everything(q='ethereum', language='en', sort_by='relevancy')
print(f"Total articles about Ethereum: {ethereum_headlines['totalResults']}")
ethereum_headlines["articles"][0]
# Out:
# Total articles about Ethereum: 4869
# {'source': {'id': 'wired', 'name': 'Wired'},
#  'author': 'Gian M. Volpicelli',
#  'title': "Ethereum's 'Merge' Is a Big Deal for Crypto—and the Planet",
#  'description': 'One of the most influential cryptocurrency projects is set to finally ditch proof-of-work mining.',
#  'url': 'https://www.wired.com/story/ethereum-merge-big-deal-crypto-environment/',
#  'urlToImage': 'https://media.wired.com/photos/62fe63bcfd602ff2f11e6fbf/191:100/w_1280,c_limit/Ethereum-Ditches-Crypto-Business-1036181110.jpg',
#  'publishedAt': '2022-08-18T16:09:33Z',
#  'content': 'Cryptocurrencies are often criticized for being bad for the planet. Every year, bitcoin mining consumes more energy than Belgium, according to the University of Cambridges Bitcoin Electricity Consump… [+3829 chars]'}

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
bitcoin_df = pd.DataFrame(bitcoin_sentiments)
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
bitcoin_df = bitcoin_df[cols]

bitcoin_df
# Out:
#           date                                               text  compound  \
# 0   2022-08-03  It was 8:45 in the morning of June 13 when Bil...    0.5574
# 1   2022-08-02  Tools to trace cryptocurrencies have, over jus...    0.0000
# 2   2022-08-18  Cryptocurrencies are often criticized for bein...   -0.5584
# 3   2022-08-02  Posted \r\nFrom Bitcoin highs to blockchain br...   -0.2960
# 4   2022-08-27  Aug 27 (Reuters) - Bitcoin was off 1.63% at $1...    0.0000
# ..         ...                                                ...       ...
# 95  2022-08-11  August 2022\r\nA criteria for judging when a\r...    0.2023
# 96  2022-08-08  7 p.m. Soccer night. I drive to the field in S...    0.0000
# 97  2022-08-19  Good Friday morning! Jordan Parker Erb here, r...    0.5010
# 98  2022-08-23  Facebook stunned the world last October when i...   -0.1027
# 99  2022-08-01  Recent years have seen a plethora of cryptocur...    0.1280
#
#     positive  negative  neutral
# 0      0.119     0.000    0.881
# 1      0.000     0.000    1.000
# 2      0.068     0.170    0.763
# 3      0.000     0.086    0.914
# 4      0.000     0.000    1.000
# ..       ...       ...      ...
# 95     0.057     0.000    0.943
# 96     0.000     0.000    1.000
# 97     0.103     0.000    0.897
# 98     0.000     0.038    0.962
# 99     0.157     0.115    0.728
#
# [100 rows x 6 columns]

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in ethereum_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
ethereum_df = pd.DataFrame(ethereum_sentiments)
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ethereum_df = ethereum_df[cols]

ethereum_df
# Out:
#           date                                               text  compound  \
# 0   2022-08-18  Cryptocurrencies are often criticized for bein...   -0.5584
# 1   2022-08-04  The non-fungible token\r\n (NFT) market has fa...   -0.0217
# 2   2022-08-02  It's a day of the week ending in the letter "y...   -0.2732
# 3   2022-08-11  Developers have picked a number of so-called t...   -0.6124
# 4   2022-08-08  BANGKOK, Aug 8 (Reuters) - Crypto exchange Zip...    0.0000
# ..         ...                                                ...       ...
# 95  2022-08-09  If you bought Ethereum(ETH -3.05%) back in Jul...    0.6486
# 96  2022-08-09  In the crypto market, it can be much more diff...   -0.4927
# 97  2022-08-09  The New Consumer— by Dan Frommer\r\nA publicat...    0.7316
# 98  2022-08-02  Valuing cryptocurrencies is difficult because ...    0.3818
# 99  2022-08-04  Right now, Ethereum(ETH -1.89%) is getting a l...    0.0000
#
#     positive  negative  neutral
# 0      0.068     0.170    0.763
# 1      0.048     0.051    0.901
# 2      0.059     0.115    0.827
# 3      0.036     0.145    0.820
# 4      0.000     0.000    1.000
# ..       ...       ...      ...
# 95     0.187     0.058    0.754
# 96     0.000     0.104    0.896
# 97     0.186     0.000    0.814
# 98     0.187     0.121    0.692
# 99     0.000     0.000    1.000
#
# [100 rows x 6 columns]

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.028193    0.061840    0.055190    0.882960
# std      0.452947    0.068611    0.071427    0.089061
# min     -0.908100    0.000000    0.000000    0.628000
# 25%     -0.296000    0.000000    0.000000    0.822250
# 50%      0.000000    0.057000    0.000000    0.882500
# 75%      0.361200    0.102250    0.115500    0.951000
# max      0.924600    0.372000    0.307000    1.000000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.174679    0.077460    0.038790    0.883790
# std      0.442409    0.071417    0.060184    0.086943
# min     -0.851900    0.000000    0.000000    0.679000
# 25%      0.000000    0.000000    0.000000    0.817750
# 50%      0.214300    0.064000    0.000000    0.889000
# 75%      0.528675    0.131250    0.056250    0.946250
# max      0.840200    0.249000    0.243000    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
nltk.download('stopwords')
sw = set(stopwords.words('english'))
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')

# Expand the default stopwords list if necessary
sw_addon = {'the'}
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\scott\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\scott\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\scott\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\scott\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    regex = re.compile("[^a-zA-Z ]")
    # Remove the punctuation from text
    re_clean = regex.sub('', text)
    sw_addon = {'the'}
    # Create a tokenized list of the words
    words = word_tokenize(re_clean)
    
    # Lemmatize words into root words
    lemmatize = [lemmatizer.lemmatize(word) for word in words]
   
    # Convert the words to lowercase & remove the stop words
    tokens = [word.lower() for word in words if word.lower() not in sw.union(sw_addon)]
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
bitcoin_df['tokens'] = bitcoin_df['text'].apply(tokenizer)
bitcoin_df
# Out:
#           date                                               text  compound  \
# 0   2022-08-03  It was 8:45 in the morning of June 13 when Bil...    0.5574
# 1   2022-08-02  Tools to trace cryptocurrencies have, over jus...    0.0000
# 2   2022-08-18  Cryptocurrencies are often criticized for bein...   -0.5584
# 3   2022-08-02  Posted \r\nFrom Bitcoin highs to blockchain br...   -0.2960
# 4   2022-08-27  Aug 27 (Reuters) - Bitcoin was off 1.63% at $1...    0.0000
# ..         ...                                                ...       ...
# 95  2022-08-11  August 2022\r\nA criteria for judging when a\r...    0.2023
# 96  2022-08-08  7 p.m. Soccer night. I drive to the field in S...    0.0000
# 97  2022-08-19  Good Friday morning! Jordan Parker Erb here, r...    0.5010
# 98  2022-08-23  Facebook stunned the world last October when i...   -0.1027
# 99  2022-08-01  Recent years have seen a plethora of cryptocur...    0.1280
#
#     positive  negative  neutral  \
# 0      0.119     0.000    0.881
# 1      0.000     0.000    1.000
# 2      0.068     0.170    0.763
# 3      0.000     0.086    0.914
# 4      0.000     0.000    1.000
# ..       ...       ...      ...
# 95     0.057     0.000    0.943
# 96     0.000     0.000    1.000
# 97     0.103     0.000    0.897
# 98     0.000     0.038    0.962
# 99     0.157     0.115    0.728
#
#                                                tokens
# 0   [morning, june, bill, stewart, ceo, mainebased...
# 1   [tools, trace, cryptocurrencies, last, several...
# 2   [cryptocurrencies, often, criticized, bad, pla...
# 3   [posted, bitcoin, highs, blockchain, bridge, l...
# 4   [aug, reuters, bitcoin, late, afternoon, europ...
# ..                                                ...
# 95  [august, criteria, judging, blockchain, applic...
# 96  [pm, soccer, night, drive, field, santa, monic...
# 97  [good, friday, morning, jordan, parker, erb, r...
# 98  [facebook, stunned, world, last, october, rebr...
# 99  [recent, years, seen, plethora, cryptocurrenci...
#
# [100 rows x 7 columns]

# %%
# Create a new tokens column for Ethereum
ethereum_df['tokens'] = ethereum_df['text'].apply(tokenizer)
ethereum_df
# Out:
#           date                                               text  compound  \
# 0   2022-08-18  Cryptocurrencies are often criticized for bein...   -0.5584
# 1   2022-08-04  The non-fungible token\r\n (NFT) market has fa...   -0.0217
# 2   2022-08-02  It's a day of the week ending in the letter "y...   -0.2732
# 3   2022-08-11  Developers have picked a number of so-called t...   -0.6124
# 4   2022-08-08  BANGKOK, Aug 8 (Reuters) - Crypto exchange Zip...    0.0000
# ..         ...                                                ...       ...
# 95  2022-08-09  If you bought Ethereum(ETH -3.05%) back in Jul...    0.6486
# 96  2022-08-09  In the crypto market, it can be much more diff...   -0.4927
# 97  2022-08-09  The New Consumer— by Dan Frommer\r\nA publicat...    0.7316
# 98  2022-08-02  Valuing cryptocurrencies is difficult because ...    0.3818
# 99  2022-08-04  Right now, Ethereum(ETH -1.89%) is getting a l...    0.0000
#
#     positive  negative  neutral  \
# 0      0.068     0.170    0.763
# 1      0.048     0.051    0.901
# 2      0.059     0.115    0.827
# 3      0.036     0.145    0.820
# 4      0.000     0.000    1.000
# ..       ...       ...      ...
# 95     0.187     0.058    0.754
# 96     0.000     0.104    0.896
# 97     0.186     0.000    0.814
# 98     0.187     0.121    0.692
# 99     0.000     0.000    1.000
#
#                                                tokens
# 0   [cryptocurrencies, often, criticized, bad, pla...
# 1   [nonfungible, token, nft, market, fallen, clif...
# 2   [day, week, ending, letter, inevitably, means,...
# 3   [developers, picked, number, socalled, total, ...
# 4   [bangkok, aug, reuters, crypto, exchange, zipm...
# ..                                                ...
# 95  [bought, ethereumeth, back, july, first, launc...
# 96  [crypto, market, much, difficult, longterm, in...
# 97  [new, consumer, dan, frommera, publication, pe...
# 98  [valuing, cryptocurrencies, difficult, fundame...
# 99  [right, ethereumeth, getting, lot, attention, ...
#
# [100 rows x 7 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
bitcoin_text = ' '.join(bitcoin_df.text)
bitcoin_processed = tokenizer(bitcoin_text)
bitcoin_ngrams = Counter(ngrams(bitcoin_processed, n=2))
print(dict(bitcoin_ngrams.most_common(10)))
# Out:
# {('aug', 'reuters'): 27, ('chars', 'us'): 16, ('us', 'stocks'): 16, ('chars', 'aug'): 10, ('federal', 'reserve'): 6, ('worlds', 'biggest'): 5, ('chars', 'bitcoin'): 5, ('bitcoin', 'mining'): 4, ('chars', 'london'): 4, ('london', 'aug'): 4}

# %%
# Generate the Ethereum N-grams where N=2
ethereum_text = ' '.join(ethereum_df.text)
ethereum_processed = tokenizer(ethereum_text)
ethereum_ngrams = Counter(ngrams(ethereum_processed, n=2))
print(dict(ethereum_ngrams.most_common(10)))
# Out:
# {('aug', 'reuters'): 7, ('ethereum', 'blockchain'): 6, ('chars', 'us'): 5, ('chars', 'new'): 5, ('crypto', 'market'): 5, ('chars', 'crypto'): 4, ('tornado', 'cash'): 4, ('retail', 'investors'): 4, ('chars', 'nonfungible'): 3, ('september', 'ethereum'): 3}

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
top_10_bitcoin = token_count(bitcoin_ngrams, 10)
top_10_bitcoin
# Out:
# [(('aug', 'reuters'), 27),
#  (('chars', 'us'), 16),
#  (('us', 'stocks'), 16),
#  (('chars', 'aug'), 10),
#  (('federal', 'reserve'), 6),
#  (('worlds', 'biggest'), 5),
#  (('chars', 'bitcoin'), 5),
#  (('bitcoin', 'mining'), 4),
#  (('chars', 'london'), 4),
#  (('london', 'aug'), 4)]

# %%
# Use token_count to get the top 10 words for Ethereum
top_10_ethereum = token_count(ethereum_ngrams, 10)
top_10_ethereum
# Out:
# [(('aug', 'reuters'), 7),
#  (('ethereum', 'blockchain'), 6),
#  (('chars', 'us'), 5),
#  (('chars', 'new'), 5),
#  (('crypto', 'market'), 5),
#  (('chars', 'crypto'), 4),
#  (('tornado', 'cash'), 4),
#  (('retail', 'investors'), 4),
#  (('chars', 'nonfungible'), 3),
#  (('september', 'ethereum'), 3)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_63272/2772510350.py in <module>
# ----> 1 from wordcloud import WordCloud
#       2 import matplotlib.pyplot as plt
#       3 plt.style.use('seaborn-whitegrid')
#       4 import matplotlib as mpl
#       5 mpl.rcParams['figure.figsize'] = [20.0, 10.0]
#
# c:\Users\scott\anaconda3\envs\pyvizenv\envs\pyvizenv2\lib\site-packages\wordcloud\__init__.py in <module>
# ----> 1 from .wordcloud import (WordCloud, STOPWORDS, random_color_func,
#       2                         get_single_color_func)
#       3 from .color_from_image import ImageColorGenerator
#       4
#       5 __all__ = ['WordCloud', 'STOPWORDS', 'random_color_func',
#
# c:\Users\scott\anaconda3\envs\pyvizenv\envs\pyvizenv2\lib\site-packages\wordcloud\wordcloud.py in <module>
#      26 from PIL import ImageDraw
#      27 from PIL import ImageFilter
# ---> 28 from PIL import ImageFont
#      29
#      30 from .query_integral_image import query_integral_image
#
# c:\Users\scott\anaconda3\envs\pyvizenv\envs\pyvizenv2\lib\site-packages\PIL\ImageFont.py in <module>
#      35 from . import Image
#      36 from ._deprecate import deprecate
# ---> 37 from ._util import is_directory, is_path
#      38
#      39
#
# ImportError: cannot import name 'is_directory' from 'PIL._util' (c:\Users\scott\anaconda3\envs\pyvizenv\envs\pyvizenv2\lib\site-packages\PIL\_util.py)

# %%
# Generate the Bitcoin word cloud
bitcoin_cloud = WordCloud().generate(bitcoin_text)
plt.imshow(bitcoin_cloud)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_63272/2082948699.py in <module>
#       1 # Generate the Bitcoin word cloud
# ----> 2 bitcoin_cloud = WordCloud().generate(bitcoin_text)
#       3 plt.imshow(bitcoin_cloud)
#
# NameError: name 'WordCloud' is not defined

# %%
# Generate the Ethereum word cloud
ethereum_cloud = WordCloud().generate(ethereum_text)
plt.imshow(ethereum_cloud)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
bitcoin_text
# Out:
# 'It was 8:45 in the morning of June 13 when Bill Stewart, the CEO of Maine-based bitcoin mining business Dynamics Mining, received a call from one of his employees. He\'s like, Every machine inside of … [+3472 chars] Tools to trace cryptocurrencies have, over just the last several years, allowed law enforcement agencies to convict dark web black market administrators, recover millions in ransomware payments, seiz… [+3510 chars] Cryptocurrencies are often criticized for being bad for the planet. Every year, bitcoin mining consumes more energy than Belgium, according to the University of Cambridges Bitcoin Electricity Consump… [+3829 chars] Posted \r\nFrom Bitcoin highs to blockchain bridge lows, to why some of the worlds biggest technology companies are freezing jobs, we round up the weeks big stories in the world of virtual money. Krist… [+17 chars] Aug 27 (Reuters) - Bitcoin was off 1.63% at $19,920 by late afternoon in Europe on Saturday, down $330 from its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is down 58… [+336 chars] Bitcoin advanced to $24,000 for the first time in August, a move taking place before financial markets assess a high-profile reading of US inflation this week.\xa0\r\nBitcoin rose as much as 4% to $24,191… [+1770 chars] Aug 2 (Reuters) - It\'s been a good month for bitcoin - and we haven\'t said that for a while.\r\nAfter months of freefall, it jumped more than 17% in July, its best performance since October. Ether rose… [+3538 chars] July 30 (Reuters) - Bitcoin rose 3.36% to $24,584.24 at 1707 GMT on Saturday, adding $798.93 to its previous close.\r\nBitcoin, the world\'s biggest, best-known cryptocurrency, is up 39.7% from the year… [+345 chars] SINGAPORE, Aug 19 (Reuters) - Cryptocurrencies fell sharply on Friday, with sudden selling dragging bitcoin to a three-week low.\r\nThe reason for the drop was not immediately clear. Bitcoin fell as mu… [+312 chars] "Not your keys, not your coin" is a popular saying within some parts of the cryptocurrency community. It\'s a reminder that if you choose to store your bitcoin on a cryptocurrency exchange account, th… [+7518 chars] Aug 11 (Reuters) - BlackRock Inc (BLK.N), the world\'s biggest asset manager, has launched a spot bitcoin private trust for institutional clients in the United States, according to a blog post on its … [+1171 chars] Posted \r\nFrom bitcoins big slide back towards $20,000 to what a court says you cant buy with Central African Republics new coin, we round up the week\'s big stories in the world of virtual money. Trev… [+17 chars] Aug 30 (Reuters) - Who can save bitcoin?\r\nThe world\'s biggest cryptocurrency can\'t seem to catch a break. It finally looked to be regaining strength this month, breaching $25,000 for the first time s… [+3695 chars] Ive been writing about cryptocurrency for my entire career. In that time, one point Ive always stuck to is simple: dont listen to me for investment advice. Today, I want to quantify why.\r\nBitcoin was… [+7658 chars] MicroStrategy\'s founder Michael Saylor will step down as CEO, with the move coming after the enterprise software maker took a quarterly impairment charge of more than $900 million related to the drop… [+1552 chars] Bitcoin mining is a crucial part of the cryptocurrency\'s underlying technology through which transactions are verified and added to the digital ledger known as blockchain. The owners and operators of… [+7864 chars] When you think about investing, the idea is usually that you profit when the price of an asset increases, and lose money when it falls.\r\nAnother, more-advanced approach is short-selling, or shorting.… [+8172 chars] Despite its somewhat nebulous-seeming nature, Bitcoin is a finite resource. There will only ever be 21 million Bitcoin. So far, 19 million have already been mined, meaning there\'s just two million Bi… [+6317 chars] Not a day goes by without bitcoin being in the news. And given the cryptocurrency\'s phenomenal pric ...

# %%
# Run the NER processor on all of the text
bitcoin_doc = nlp(bitcoin_text)

# Add a title to the document
bitcoin_doc.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(bitcoin_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">It was
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8:45 in the morning of June 13
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  when
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bill Stewart
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the CEO of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -based bitcoin mining business
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dynamics Mining
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , received a call from one of his employees. He's like, Every machine inside of … [+3472 chars] Tools to trace cryptocurrencies have, over just
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last several years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , allowed law enforcement agencies to convict dark web black market administrators, recover
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     millions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  in ransomware payments, seiz… [+3510 chars] Cryptocurrencies are often criticized for being bad for the planet.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Every year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , bitcoin mining consumes more energy than
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Belgium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , according to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the University of Cambridges Bitcoin Electricity Consump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>From Bitcoin highs to blockchain bridge lows, to why some of the worlds biggest technology companies are freezing jobs, we round up
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  big stories in the world of virtual money.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Krist
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# … [+17 chars] Aug 27 (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Bitcoin was off
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1.63%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  at $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     19,920
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     late afternoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Saturday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , down $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     330
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>Bitcoin, the world's biggest and best-known cryptocurrency, is down
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     58
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# … [+336 chars] Bitcoin advanced to $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     24,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  for the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  time in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     August
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , a move taking place before financial markets assess a high-profile reading of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-he

# %%
# List all Entities
for ent in bitcoin_doc.ents:
    print(ent.text, ent.label_)
# Out:
# 8:45 in the morning of June 13 TIME
# Bill Stewart PERSON
# Maine GPE
# Dynamics Mining ORG
# the last several years DATE
# millions CARDINAL
# Every year DATE
# Belgium GPE
# the University of Cambridges Bitcoin Electricity Consump ORG
# the weeks DATE
# Krist ORG
# Reuters ORG
# 1.63% PERCENT
# 19,920 MONEY
# late afternoon TIME
# Europe LOC
# Saturday DATE
# 330 MONEY
# 58 CARDINAL
# 24,000 MONEY
# first ORDINAL
# August DATE
# US GPE
# this week DATE
# as much as 4% PERCENT
# 24,191 MONEY
# Reuters ORG
# a good month DATE
# months DATE
# more than 17% PERCENT
# July DATE
# October DATE
# July 30 DATE
# Reuters ORG
# 3.36% PERCENT
# 24,584.24 MONEY
# GMT WORK_OF_ART
# Saturday DATE
# 798.93 MONEY
# 39.7% PERCENT
# the year DATE
# Aug 19 DATE
# Reuters ORG
# Friday DATE
# three-week DATE
# Reuters ORG
# the United States GPE
# 20,000 MONEY
# Central African Republics ORG
# week DATE
# Reuters ORG
# this month DATE
# 25,000 MONEY
# first ORDINAL
# one CARDINAL
# Today DATE
# MicroStrategy ORG
# Michael Saylor PERSON
# quarterly DATE
# more than $900 million MONEY
# 21 million CARDINAL
# 19 million CARDINAL
# just two million CARDINAL
# zero CARDINAL
# approximately $32,000 MONEY
# Reuters ORG
# The U.S. Department of Justice ORG
# Celsius Networks' ORG
# +3074 PERSON
# Jack Dorsey PERSON
# Twitter ORG
# This week DATE
# Reuters ORG
# Ethereum and Bitcoin ORG
# this week DATE
# Monday DATE
# 60% PERCENT
# the Tysons Corner ORG
# Virginia GPE
# 1989 DATE
# Bitcoin NORP
# MicroStrategy ORG
# Phong Le GPE
# +922 PERSON
# LONDON GPE
# Aug 18 DATE
# Reuters ORG
# 6TJ.SG CARDINAL
# Thursday DATE
# Vinanz Ltd ORG
# 24% PERCENT
# Friday DATE
# second-quarter DATE
# Coinbase PERSON
# Coinbase PRODUCT
# Matt Turner PERSON
# Insider Weekly ORG
# today DATE
# Ben Tobin PERSON
# GPV ORG
# 23% PERCENT
# year DATE
# year DATE
# YoY ORG
# Q2 CARDINAL
# 88% PERCENT
# YoY ORG
# the same period last year DATE
# Robert Kiyosaki PERSON
# Satoshi Nakamoto PERSON
# British NORP
# Peter McCormack PERSON
# Reuters ORG
# Jack Dorsey- PERSON
# Block Inc ORG
# Thursday DATE
# the second quarter DATE
# Reuters ORG
# Jack Dorsey- PERSON
# Block Inc ORG
# nearly 7% PERCENT
# Friday DATE
# Coinbase PERSON
# 2022 DATE
# the year DATE
# Mike Novogratz PERSON
# WASHINGTON GPE
# 3 CARDINAL
# Reuters ORG
# the U.S. Senate ORG
# the Commodity Futures Trading Commission ORG
# CFTC ORG
# Reuters ORG
# Celsius Network PERSON
# Tuesday DATE
# U.S. GPE
# U.S. GPE
# Martin Glenn PERSON
# Manhatt ORG
# approximately £150m MONEY
# thousands of tonnes QUANTITY
# LONDON GPE
# Aug 11 DATE
# Reuters ORG
# $3.12 trillion MONEY
# July DATE
# 13% PERCENT
# monthly DATE
# CryptoCompare ORG
# Thursday DATE
# pri ORG
# James Howells PERSON
# 8,000 CARDINAL
# 2013 DATE
# the years DATE
# November 2021 DATE
# Joe Hovde PERSON
# New York GPE
# today DATE
# third ORDINAL
# two CARDINAL
# Silicon Valley LOC
# third ORDINAL
# 15 September DATE
# Digital ORG
# $554.7 million MONEY
# the second quarter DATE
# 2021 DATE
# Monday DATE
# downbeat CARDINAL
# about 8% PERCENT
# Friday DATE
# Fed ORG
# 21,438 MONEY
# Friday DATE
# 8:30 a.m. TIME
# ET PERSON
# Reuters ORG
# Constitutional Court ORG
# Monday DATE
# Reuters ORG
# CBOE.Z PRODUCT
# Thursday DATE
# US GPE
# Thursday DATE
# the Federal Reserve ORG
# Nasdaq ORG
# 10-year DATE
# Treasury ORG
# Bitcoin NORP
# 3 CARDINAL
# as much as 75% PERCENT
# JPMorgan ORG
# Monday DATE
# 36% PERCENT
# 102% PERCENT
# mid-June DATE
# recent weeks DATE
# Bank of America ORG
# NFL ORG
# Tom Brady PERSON
# 45-year-old DATE
# NFT ORG
# Yacht Club ORG
# April DATE
# Reuters ORG
# the second quarter DATE
# Tuesday DATE
# year DATE
# NEW YORK GPE
# Aug 8 DATE
# Reuters ORG
# first ORDINAL
# BitMEX PERSON
# Monday DATE
# U.S. GPE
# LONDON GPE
# 3 CARDINAL
# Reuters ORG
# The European Union's ORG
# Thailand GPE
# Friday DATE
# late this year DATE
# the middle of 2023 DATE
# LONDON GPE
# Aug 12 DATE
# Reuters ORG
# British NORP
# ABDN.L PRODUCT
# digital ORG
# Archax ORG
# NEW YORK GPE
# Aug 16 DATE
# Reuters ORG
# nearly 60% PERCENT
# the first seven months of the year DATE
# $1.9 billion MONEY
# Reuters ORG
# U.S. GPE
# Tuesday DATE
# Uber Technologies Inc ORG
# 2016 DATE
# Alun John
# Fed ORG
# last night TIME
# SYDNEY GPE
# 26 CARDINAL
# Reuters ORG
# Australian NORP
# Jack Dorsey's PERSON
# Block Inc ORG
# Australia GPE
# Westpac Banking Corp ORG
# WBC.AX ORG
# US GPE
# Bitcoin NORP
# ISpot.tv GPE
# Tiffany Fong PERSON
# 2022 DATE
# Solana PERSON
# early Wednesday DATE
# Nomad ORG
# 7,767 CARDINAL
# US GPE
# Wednesday DATE
# Federal Reserve ORG
# US GPE
# Friday DATE
# Federal Reserve ORG
# next month's DATE
# 2021 DATE
# 50% PERCENT
# 42,733 MONEY
# 2022 DATE
# 24,109 MONEY
# Voyager PRODUCT
# US GPE
# Monday DATE
# midweek DATE
# Presid ORG
# US GPE
# the Federal Reserve ORG
# China GPE
# Democrat NORP
# Maxine Waters PERSON
# US GPE
# Thursday DATE
# 0.5% PERCENT
# June to July DATE
# first ORDINAL
# US GPE
# Wednesday DATE
# Target ORG
# minutes TIME
# the Federal Reserve's ORG
# July DATE
# Target ORG
# 2% PERCENT
# second-quarter DATE
# Sam Bankman-Fried's PERSON
# FTX ORG
# more than 1,000% PERCENT
# 2021 DATE
# CNBC ORG
# $89 million MONEY
# 2020 DATE
# US GPE
# Thursday DATE
# weekly DATE
# 2,000 to 250,000 CARDINAL
# last week DATE
# US GPE
# Monday DATE
# the Federal Reserve's ORG
# Fed ORG
# Jerome Powell PERSON
# third ORDINAL
# US GPE
# Tuesday DATE
# Home Depot ORG
# Walmart ORG
# Walmart ORG
# 4.25 CARDINAL
# US GPE
# Tuesday DATE
# two months a day earlier DATE
# more than 600 CARDINAL
# Monday DATE
# 15 CARDINAL
# Reuters ORG
# Australian NORP
# two-month DATE
# Monday DATE
# China GPE
# US GPE
# Thursday DATE
# Wednesday DATE
# roughly 1.5% PERCENT
# US GPE
# Monday DATE
# Nvidia ORG
# second-quarter DATE
# $6.7 billion MONEY
# US GPE
# Friday DATE
# 500 CARDINAL
# month-to-date DATE
# about 2% PERCENT
# 1.4% PERCENT
# July DATE
# ec ORG
# US GPE
# Wednesday DATE
# five-day DATE
# Us GPE
# Monday DATE
# Friday DATE
# Federal Reserve ORG
# Jerome Powell PERSON
# Friday DATE
# Wyomi ORG
# US GPE
# Friday DATE
# Federal Reserve ORG
# Jerome Powell's PERSON
# Jackson Hole GPE
# Wyoming GPE
# 10:00 a.m. TIME
# ET PERSON
# 4 CARDINAL
# Reuters ORG
# Thursday DATE
# U.S. Federal Reserve ORG
# HONG KONG GPE
# 17 CARDINAL
# Reuters ORG
# Wednesday DATE
# a Reserve Bank of New Zealand ORG
# HONG KONG GPE
# 2 CARDINAL
# Reuters ORG
# Tuesday DATE
# two months DATE
# Japanese NORP
# SYDNEY GPE
# Reuters ORG
# Nearly half CARDINAL
# Australian NORP
# late 2021 DATE
# YouTube ORG
# Reuters ORG
# Asian NORP
# Wednesday DATE
# U.S. GPE
# the Federal Reserve's ORG
# s ORG
# Transform 2022 LAW
# Last month DATE
# roughly $100 million MONEY
# Harmon ORG
# Bitcoin NORP
# second ORDINAL
# more than 99% PERCENT
# the next month DATE
# August 2022 DATE
# 7 p.m. Soccer night TIME
# Santa Monica GPE
# @nftsonbitcoin ORG
# IG ORG
# two CARDINAL
# first ORDINAL
# one CARDINAL
# Friday DATE
# morning TIME
# Jordan Parker Erb PERSON
# Montana GPE
# +4369 PERSON
# last October DATE
# Meta WORK_OF_ART
# the past two decades DATE
# the Great Financial Crisis EVENT
# 2008 DATE
# Today DATE
# +5302 chars] ORG

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
ethereum_text = ' '.join(ethereum_df.text)
ethereum_text
# Out:
# 'Cryptocurrencies are often criticized for being bad for the planet. Every year, bitcoin mining consumes more energy than Belgium, according to the University of Cambridges Bitcoin Electricity Consump… [+3829 chars] The non-fungible token\r\n (NFT) market has fallen off a cliff\r\n, but that\'s not stopping Instagram from doubling down on digital collectibles. After a test launch in May\r\n, the app is expanding its NF… [+1097 chars] It\'s a day of the week ending in the letter "y," which inevitably means there\'s news of another\r\nmessy\r\nsaga\r\n in the cryptocurrency world. The Securities and Exchange Commission has charged 11 peopl… [+1855 chars] Developers have picked a number of so-called total terminal difficulty required of the final block mined in Ethereum before the network switches to new software. Figuring out the exact date range whe… [+1084 chars] BANGKOK, Aug 8 (Reuters) - Crypto exchange Zipmex will release Ethereum and Bitcoin tokens from this week, a spokesperson said on Monday, allowing 60% of its customers to retrieve their digital asset… [+874 chars] On 15 September, the ethereum blockchain is planning to switch off its mining rigs. If it happens, it should reduce the carbon emissions of the entire ethereum ecosystem by orders of magnitude overni… [+8773 chars] Some crypto critics like Vivaldi CEO Jon von Tetzchner have called the entire apparatus of crypto nothing more than a pyramid scheme. Its an easy claim when you cite the ever-growing number of scams … [+3393 chars] The US Treasury Department\'s Office of Foreign Asset Control on Monday sanctioned crypto platform Tornado Cash, which North Korean hackers have used for laundering.\xa0\r\nThe sanctions prohibit any Ameri… [+2121 chars] After bitcoin fell as much as 75% from its peak, crypto markets appear to have "found a floor," JPMorgan said in a note on Monday.\xa0\r\nBitcoin and ether have surged 36% and 102% from their mid-June low… [+1887 chars] Ethereum, the second largest cryptocurrency, will complete a plan to lower its carbon emissions by more than 99% in the next month, the foundation that controls the platform has confirmed.\r\nThe proje… [+4142 chars] "When members of the ENS DAO community go to its eth.link website, all they\'ll see now is an empty page with a green domain expiration notice banner at the top," reports CoinDesk."That\'s because the … [+1156 chars] When he speaks to clubs across Europe who want to launch NFTs, their primary concern is money. The number one thing is, Oh, we want to make millions of pounds overnight, Mangnall says. Theres a real … [+3005 chars] Back in November 2021, cryptocurrencies, which saw a huge surge during most of the pandemic, suddenly began to nosedive. Joe Hovde, a New York-based data scientist, decided that this might be his mom… [+1641 chars] July 30 (Reuters) - Bitcoin rose 3.36% to $24,584.24 at 1707 GMT on Saturday, adding $798.93 to its previous close.\r\nBitcoin, the world\'s biggest, best-known cryptocurrency, is up 39.7% from the year… [+345 chars] Aug 27 (Reuters) - Bitcoin was off 1.63% at $19,920 by late afternoon in Europe on Saturday, down $330 from its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is down 58… [+336 chars] <ul><li>Ethereum is moving to proof-of-stake! The transition, known as The Merge, must first be activated on the Beacon Chain with the Bellatrix upgrade. After this, the proof-of-work chain will migr… [+11369 chars] The highly anticipated Ethereum Merge that is expected next month could ultimately prove to be a "sell the news" event for ether prices, according to Glassnode.\r\nThe Ethereum blockchain is expected t… [+2277 chars] LONDON, Aug 11 (Reuters) - Cryptocurrency derivatives trading on centralised exchanges rose to $3.12 trillion in July, a 13% monthly increase, researcher CryptoCompare said on Thursday, as crypto pri… [+2234 chars] Billionaire bitcoin bull Mike Novogratz believes the forced deleveraging of the cryptocurrenc ...

# %%
# Run the NER processor on all of the text
ethereum_doc = nlp(ethereum_text)

# Add a title to the document
ethereum_doc.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(ethereum_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Cryptocurrencies are often criticized for being bad for the planet.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Every year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , bitcoin mining consumes more energy than
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Belgium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , according to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the University of Cambridges Bitcoin Electricity Consump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br> (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>, but that's not stopping
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Instagram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  from doubling down on digital collectibles. After a test launch in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>, the app is expanding its
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br> in the cryptocurrency world.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Securities and Exchange Commission
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has charged
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  peopl… [+1855 chars] Developers have picked a number of so-called total terminal difficulty required of the final block mined in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  before the network switches to new software. Figuring out the exact date range whe… [+1084 chars] BANGKOK, Aug 8 (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Crypto exchange Zipmex will release
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum and Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  tokens from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , a spokesperson said on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , allowing
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     60%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  of its customers to retrieve their digital asset… [+874 chars] On
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15 September
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the ethereum blockchain is planning to switch off its mining rigs. If it happens, it should reduce the carbon emissions of the entire ethereum ecosystem by orders of magnitude overni… [+8773 chars] Some crypto critics like
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vivaldi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  CEO
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jon von Tetzchner
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  have called the entire apparatus of crypto nothing more than a pyramid scheme. Its an easy claim when you cite the ever-growing number of scams … [
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     +3393
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  chars]
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The US Treasury Department's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Office of Foreign Asset Control
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE<

# %%
# List all Entities
for ent in ethereum_doc.ents:
    print(ent.text, ent.label_)
# Out:
# Every year DATE
# Belgium GPE
# the University of Cambridges Bitcoin Electricity Consump ORG
# NFT ORG
# Instagram ORG
# May DATE
# NF ORG
# The Securities and Exchange Commission ORG
# 11 CARDINAL
# Ethereum ORG
# Reuters ORG
# Ethereum and Bitcoin ORG
# this week DATE
# Monday DATE
# 60% PERCENT
# 15 September DATE
# Vivaldi PERSON
# Jon von Tetzchner PERSON
# +3393 ORG
# The US Treasury Department's ORG
# Office of Foreign Asset Control ORG
# Monday DATE
# Tornado Cash PERSON
# North Korean NORP
# Ameri ORG
# as much as 75% PERCENT
# JPMorgan ORG
# Monday DATE
# 36% PERCENT
# 102% PERCENT
# mid-June DATE
# second ORDINAL
# more than 99% PERCENT
# the next month DATE
# ENS ORG
# eth.link PERSON
# CoinDesk PRODUCT
# Europe LOC
# one CARDINAL
# millions of pounds QUANTITY
# Mangnall PERSON
# November 2021 DATE
# Joe Hovde PERSON
# New York GPE
# July 30 DATE
# Reuters ORG
# 3.36% PERCENT
# 24,584.24 MONEY
# GMT WORK_OF_ART
# Saturday DATE
# 798.93 MONEY
# 39.7% PERCENT
# the year DATE
# Reuters ORG
# 1.63% PERCENT
# 19,920 MONEY
# late afternoon TIME
# Europe LOC
# Saturday DATE
# 330 MONEY
# 58 CARDINAL
# Bellatrix ORG
# Ethereum Merge ORG
# next month DATE
# Glassnode ORG
# Ethereum ORG
# LONDON GPE
# Aug 11 DATE
# Reuters ORG
# $3.12 trillion MONEY
# July DATE
# 13% PERCENT
# monthly DATE
# CryptoCompare ORG
# Thursday DATE
# pri ORG
# Mike Novogratz PERSON
# Hetzner PERSON
# Stephen Curry PERSON
# Curry ORG
# Curry LOC
# winter DATE
# An estimated $200 million MONEY
# Nomad ORG
# NEW YORK GPE
# 3 CARDINAL
# Reuters ORG
# Coinbase Global Inc ORG
# Wednesday DATE
# U.S. GPE
# first ORDINAL
# Reuters ORG
# 2022 DATE
# about $61 billion MONEY
# 2022 CARDINAL
# Ethereum ORG
# The US Treasury ORG
# Tornado Cash PERSON
# Monday DATE
# US GPE
# Tornado Cash PERSON
# Ethereum ORG
# +1073 PERSON
# Peter Thiel PERSON
# 100,000 MONEY
# 11 years DATE
# Silicon Valley LOC
# Trump ORG
# Thiel PERSON
# the Ethereum Merge ORG
# mid-September DATE
# Ropsten PERSON
# Sepolia GPE
# Cuban NORP
# Last November DATE
# the Great Financial Crisis EVENT
# 2008 DATE
# Today DATE
# +5302 chars ORG
# US GPE
# Thursday DATE
# 0.5% PERCENT
# June to July DATE
# first ORDINAL
# The Netherlands Crime Agency ORG
# 29-year-old DATE
# Tornado Cash PERSON
# US GPE
# earlier this week DATE
# s ORG
# about a month DATE
# Ethereum ORG
# Phil Rosen PERSON
# Manhattan GPE
# some weeks DATE
# the west coast LOC
# NYT ORG
# Ethereum Foundation ORG
# Last week DATE
# Facebooks ORG
# Meta ORG
# BlenderBot 3 LAW
# Metas ORG
# The Securities and Exchange Commission ORG
# Monday DATE
# 11 CARDINAL
# more than $300 million MONEY
# millions CARDINAL
# recent weeks DATE
# Bank of America ORG
# Mark Cuban PERSON
# Shark Tank WORK_OF_ART
# YouTube ORG
# Daily DATE
# Sunday DATE
# Bed Bath PERSON
# Beyond ORG
# Vanda Research ORG
# 7 p.m. Soccer night TIME
# Santa Monica GPE
# @nftsonbitcoin ORG
# IG ORG
# two CARDINAL
# first ORDINAL
# one CARDINAL
# 19 CARDINAL
# Reuters ORG
# U.S. GPE
# one-month DATE
# Friday DATE
# Federal Reserve ORG
# NEW YORK GPE
# Aug 16 DATE
# Reuters ORG
# nearly 60% PERCENT
# the first seven months of the year DATE
# $1.9 billion MONEY
# just two CARDINAL
# 3 MONEY
# US GPE
# Tuesday DATE
# Europe LOC
# Asia LOC
# US GPE
# season DATE
# this year DATE
# Riot Bl PERSON
# ADA ORG
# third ORDINAL
# Bitcoin and Ethereum ORG
# Cardano PERSON
# Ethereum ORG
# 2021 DATE
# 50% PERCENT
# 42,733 MONEY
# 2022 DATE
# 24,109 MONEY
# Voyager PRODUCT
# Mark Zuckerberg PERSON
# eight years old DATE
# Thursday DATE
# Instagram ORG
# Monday DATE
# the week DATE
# July DATE
# US GPE
# Federal Reserve ORG
# US GPE
# US GPE
# Wednesday DATE
# US GPE
# the Federal Reserve's ORG
# second-quarter DATE
# US GPE
# Thursday DATE
# US GPE
# July DATE
# the Federal Reserve ORG
# Sept. 15 DATE
# Dan Frommer
#  PERSON
# Transform 2022 LAW
# Transform 2022 LAW
# Mark Zuckerberg PERSON
# Meta ORG
# Dan Frommer
#  PERSON
# LWN.net
#  ORG
# LWN ORG
# Thousands CARDINAL
# LWN PERSON
# 2.13% PERCENT
# Merge PERSON
# Ethereum ORG
# 2013 DATE
# Vitalik Buterin PERSON
# Buterin PERSON
# NEW YORK GPE
# AP ORG
# Allie Tarantino PERSON
# years ago DATE
# Mark Zuckerberg PERSON
# one CARDINAL
# 8,458,650.00 MONEY
# 5,000 CARDINAL
# Ethereum ORG
# -0.83% PERCENT
# recent weeks DATE
# "The Merge WORK_OF_ART
# Last month DATE
# Ethereum ORG
# Last month DATE
# SFGate.com ORG
# San Francisco's GPE
# first ORDINAL
# NFT ORG
# Japanese NORP
# Sho Club Sky L ORG
# Tiffany Fong PERSON
# 2022 DATE
# Francophone Africa GPE
# Nelly Chatue-Diop PERSON
# Douala GPE
# last October DATE
# Meta WORK_OF_ART
# the past two decades DATE
# NFT ORG
# last month DATE
# week DATE
# Friday DATE
# Coinbase Global  PERSON
# 4.67% PERCENT
# Ethereum ORG
# Ethereum ORG
# as early as September DATE
# Ethereum ORG
# 6.33% PERCENT
# 18 CARDINAL
# 3 CARDINAL
# SOTD ORG
# Devel PERSON
# Nat PERSON
# 2013 DATE
# Ethereum ORG
# Ethereum ORG
# Ethereum(ETH -2.83% ORG
# recent weeks DATE
# the past month DATE
# nearly 55% PERCENT
# sett PERSON
# -0.77% PERCENT
# third ORDINAL
# the last few weeks DATE
# Ethereum ORG
# -1.79% PERCENT
# This summer DATE
# 4.76% PERCENT
# Merge PERSON
# Ether GPE
# 1.74% PERCENT
# Sept. 15 DATE
# Ethereum's(ETH -4.71% PERCENT
# Merge PERSON
# second ORDINAL
# a quarter CARDINAL
# Duncan* PERSON
# the start of this year DATE
# almost the entire summer DATE
# -8.96% PERCENT
# September DATE
# Ethereum ORG
# -3.05% PERCENT
# July 2015 DATE
# 47,000% PERCENT
# Dan Frommer
#  PERSON
# -0.90% PERCENT
# -1.89% PERCENT
# Merge PERSON
# September 19 DATE

# %% [markdown]
# ---
